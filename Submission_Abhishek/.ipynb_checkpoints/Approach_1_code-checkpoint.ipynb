# %% [markdown]
# ## <center>Identify online patient conversations

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
import matplotlib.pyplot as plt
import plotly.figure_factory as ff
from IPython.display import HTML, display, SVG
from IPython.core import display as ICD
from plotly.offline import init_notebook_mode, iplot

import math
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.regularizers import L1L2
from keras.utils.np_utils import to_categorical
from keras.utils.vis_utils import model_to_dot

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.grid_search import GridSearchCV
import xgboost
import lightgbm

import nltk
import string
from nltk.stem import WordNetLemmatizer, SnowballStemmer

import warnings
warnings.filterwarnings('ignore')
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def as_keras_metric(method):
    import functools
    from keras import backend as K
    import tensorflow as tf
    @functools.wraps(method)
    def wrapper(self, args, **kwargs):
        """ Wrapper for turning tensorflow metrics into keras metrics """
        value, update_op = method(self, args, **kwargs)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([update_op]):
            value = tf.identity(value)
        return value
    return wrapper

@as_keras_metric
def auc_pr(y_true, y_pred, curve='PR'):
    return tf.metrics.auc(y_true, y_pred, curve=curve)

# %%
def batch_generator_shuffle(X_data, y_data, batch_size):
    samples_per_epoch = X_data.shape[0]
    number_of_batches = samples_per_epoch/batch_size
    counter=0
    index = np.arange(np.shape(y_data)[0])
    np.random.shuffle(index)
    while 1:
        index_batch = index[batch_size*counter:batch_size*(counter+1)]
        X_batch = X_data[index_batch,:]
        y_batch = y_data[index_batch]
        counter += 1
        yield X_batch,y_batch
        if (counter > number_of_batches):
            np.random.shuffle(index)
            counter=0

# %%
seed = 13
stemmer = SnowballStemmer("english")
lemma = WordNetLemmatizer()

le = LabelEncoder()

# %%
SOURCE_FOLDER = 'dataset/'
OUTPUT_FOLDER = 'Models_and_output/'

# %%
train_data = pd.read_csv(SOURCE_FOLDER + 'train.csv', encoding='ISO-8859-1')
test_data = pd.read_csv(SOURCE_FOLDER + 'test.csv', encoding='utf8')
test_data = test_data[test_data.columns[1:-1]]

# %%
train_data.head(30)
# Out:
#     Source                                              Host  \
# 0   FORUMS                                    cafepharma.com
# 1   FORUMS                                 www.patient.co.uk
# 2     BLOG  http://abcnewsradioonline.com/entertainment-news
# 3   FORUMS                             www.cancer-forums.net
# 4   FORUMS                                  www.diyaudio.com
# 5   FORUMS                               forum.cyclinguk.org
# 6   FORUMS                                    www.reddit.com
# 7     BLOG                   http://quranfruitz.blogspot.com
# 8   FORUMS                                        hmnews.org
# 9   FORUMS                                www.cafepharma.com
# 10  FORUMS                                   modelmayhem.com
# 11  FORUMS                           blueheronhealthnews.com
# 12    BLOG     http://medicaldevicemarkettrends.blogspot.com
# 13    BLOG                  http://www.becomerichfaster.com/
# 14  FORUMS                                      www.fark.com
# 15    BLOG                            http://news.health.com
# 16  FORUMS                                 finance.yahoo.com
# 17    BLOG                           http://wwj.cbslocal.com
# 18  FORUMS                      guboards.spokesmanreview.com
# 19    BLOG                      http://mostdiet.blogspot.com
# 20    BLOG         http://eliteathletictraining.blogspot.com
# 21  FORUMS                                    alkpathway.com
# 22  FORUMS                             www.explorerforum.com
# 23  FORUMS                         stltommorow.proboards.com
# 24    BLOG                         http://www.4-traders.com/
# 25    BLOG                              feedproxy.google.com
# 26    BLOG               http://befitweightloss.blogspot.com
# 27    BLOG                              http://drkelley.info
# 28  FORUMS                                www.xboxhacker.org
# 29    BLOG               http://dangchuatinhcon.blogspot.com
#
#                                                  Link   Date(ET)     Time(ET)  \
# 0   http://cafepharma.com/boards/threads/epstein.5...  6/15/2016     13:58:00
# 1   http://www.patient.co.uk/forums/discuss/enlarg...   5/7/2016  0.820833333
# 2   http://abcnewsradioonline.com/entertainment-ne...  4/14/2016     15:00:38
# 3   http://www.cancer-forums.net/viewtopic.php?f=1...  6/18/2016     20:46:00
# 4   http://www.diyaudio.com/forums/lounge/292252-d...  6/15/2016      3:26:00
# 5   http://forum.cyclinguk.org/viewtopic.php?f=24&...   4/6/2016      5:50:00
# 6   https://www.reddit.com/r/todayilearned/comment...   5/2/2016  0.047916667
# 7   http://quranfruitz.blogspot.com/2016/02/causes...  2/28/2016      3:20:00
# 8   http://hmnews.org/health-care-news/cluster8641...  6/15/2016     17:16:00
# 9   http://www.cafepharma.com/boards/threads/nomin...  4/29/2016     23:46:00
# 10  http://www.modelmayhem.com/forums/post/960268/...  7/15/2016     15:49:00
# 11  http://blueheronhealthnews.com/site/2016/02/22...  2/22/2016     18:52:00
# 12  http://medicaldevicemarkettrends.blogspot.com/...  4/26/2016      5:48:00
# 13  http://www.becomerichfaster.com/money-morning/...  3/18/2016     19:00:28
# 14  http://www.fark.com/comments/9116353/Now-is-wh...  4/21/2016     10:17:00
# 15  http://news.health.com/2016/03/28/do-it-yourse...  3/28/2016     15:37:07
# 16  http://finance.yahoo.com/mbview/threadview/?&b...  6/17/2016      5:24:00
# 17  http://detroit.cbslocal.com/2016/03/06/former-...   3/6/2016     12:45:51
# 18  http://guboards.spokesmanreview.com/showthread...  7/25/2016     10:42:00
# 19  http://mostdiet.blogspot.com/2016/04/pot-belly...   4/3/2016      3:18:00
# 20  http://eliteathletictraining.blogspot.com/2016...  6/21/2016     16:08:00
# 21    http://alkpathway.com/50-cytokines-tnf-il1-il6/  4/26/2016     22:51:00
# 22  http://www.explorerforum.com/forums/showthread...   4/7/2016     21:47:00
# 23  http://stltommorow.proboards.com/thread/8090/l...  6/20/2016     12:40:09
# 24  http://www.4-traders.com/NOVARTIS-AG-9364983/n...   4/2/2016     11:01:13
# 25  http://feedproxy.google.com/~r/ArtesiaNews/~3/...  7/22/2016     15:56:40
# 26  http://befitweightloss.blogspot.com/2016/03/gr...  3/22/2016     12:51:00
# 27  http://www.drkelley.info/2016/04/06/would-you-...   4/6/2016     15:03:04
# 28  http://www.xboxhacker.org/index.php?topic=7224...  6/18/2016     23:03:00
# 29  http://dangchuatinhcon.blogspot.com/2016/06/vi...  6/19/2016     19:37:00
#
#           time(GMT)                                              Title  \
# 0   6/15/2016 23:28                                            Epstein
# 1       42498.21667               Enlarged Heart.Thread Enlarged Heart
# 2    4/15/2016 0:30  Queen Latifah Joins American Heart Association...
# 3    6/19/2016 6:16                                           Bulaemia
# 4   6/15/2016 12:56               DIY Silver interconnects and RCAs???
# 5    4/6/2016 15:20                                  Personal Question
# 6       42492.44375  TIL that CVS took a $2 billion hit to annual s...
# 7   2/28/2016 13:50         Causes of Low Blood Pressure(Hypo tension)
# 8    6/16/2016 2:46  Sleep disorders may predict heart events after...
# 9    4/30/2016 9:16          Nominations for worst manager at Novartis
# 10              NaN                                                NaN
# 11  2/22/2016 23:52  Comment on This ?Low Blood Pressure Diet? is T...
# 12  4/26/2016 15:18  Blood Pressure Monitoring and Testing Market t...
# 13   3/19/2016 4:30  How Much Tax Can a Tax Man Tax if a Tax Man Ca...
# 14  4/21/2016 19:47                 (9116353) Now is when doves cry :(
# 15   3/29/2016 1:07  Do-It-Yourself Blood Pressure Checks May Help ...
# 16  6/17/2016 14:54              How big is the ALS market ? Anybody !
# 17   3/6/2016 23:15  Former First Lady Nancy Reagan Dies At 94 In C...
# 18              NaN                                                NaN
# 19   4/3/2016 12:48                   Pot belly ups heart failure risk
# 20   6/22/2016 1:38                  Is Exercise Better Than Medicine?
# 21   4/27/2016 8:21  50 Moreover, the cytokines like TNF-??, IL-1??...
# 22    4/8/2016 7:17                                       Body Bushing
# 23  6/20/2016 22:10           The ?low-hanging fruit? of police reform
# 24   4/2/2016 20:31  NOVARTIS : New analyses show Novartis' Entrest...
# 25              NaN                                                NaN
# 26  3/22/2016 22:21          Grape Eaters Tend To Have Healthier Diets
# 27    4/7/2016 0:33     Would YOU know you were having a heart attack?
# 28   6/19/2016 8:33        Botulism is outlined beyond grate hospital.
# 29   6/20/2016 5:07                        Vi?c Gn Gi? Ph?p Th?nh Th?
#
#                                       TRANS_CONV_TEXT  Patient_Tag
# 0   I don't disagree with you in principle. I'm ju...            0
# 1   I am always dizzy I get dizzy standing up so I...            1
# 2   Axelle/Bauer-Griffin/FilmMagic(NEW YORK) -- Qu...            0
# 3   I am 17 and I have been throwing up for about ...            1
# 4   Quote: Originally Posted by Boyan Silyavski Wa...            0
# 5   Theres a discussion about recumbent power on B...            0
# 6   Of course! I just got diagnosed with congestiv...            1
# 7   Blood pressure is a measurement of the pressur...            0
# 8   Other Sleep disorders may predict heart events...            0
# 9   worse manager ever??? LS out of Richmond. Ugh!...            0
# 10  Looknsee Photography wrote: When I was living ...            1
# 11  Posted by: Christian Goodman A new study revea...            0
# 12  Transparency Market Research has published a n...            0
# 13  It?s been a big week here in the UK. This week...            0
# 14  Russ1642 : So another anti-science anti-medici...            1
# 15  By Steven Reinberg HealthDay Reporter MONDAY, ...            0
# 16  that's not where the biggest opportunity is - ...            0
# 17  LOS ANGELES (AP) ? Former first lady Nancy Rea...            0
# 18  Originally Posted by Birddog Cause of death wa...            0
# 19  London: Obesity not only increases the risk of...            0
# 20  According to New York Times columnist, profess...            0
# 21  50 Moreover, the cytokines like TNF-??, IL-1??...            0
# 22  Thank you swshawaii, I plan on finishing it so...            1
# 23  A little more than a year ago, my colleagues a...            0
# 24  (4-traders.com) Novartis International AG / Ne...            0
# 25  STILLWATER, Okla. (AP) ? Medical examiner spok...            0
# 26  If you?re a regular eater of grapes, then the ...            0
# 27  Warning signs can vary wildly between men and ...            0
# 28  Blood pressure sometimes ski diagnosis. Doctor...            0
# 29  41. Excerpts from vietcatholic.net tabernacle ...            0

# %%
train_data = train_data[train_data['TRANS_CONV_TEXT'].notnull()]

# %%
le.fit(train_data.Source)
train_source = le.transform(train_data.Source)

train_data.Patient_Tag.value_counts().plot('bar')

# %%
X_train = train_data['TRANS_CONV_TEXT']
Y_train = train_data['Patient_Tag']
Y_train = to_categorical(Y_train)

# %%
def preprocess_data(X_train, stemmer, lemma):
    preprocessed_data = []
    trans = str.maketrans('/(){}', ' ' * 5)
    trans_punc = str.maketrans('', '', string.punctuation)

    for text in X_train:
        text = text.lower().translate(trans)
        text = text.translate(trans_punc)
        text = [lemma.lemmatize(word) for word in text.split()]
        preprocessed_data.append(' '.join(text))

    return preprocessed_data

# %%
preprocessed_data = preprocess_data(X_train, stemmer, lemma)

# %%
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english', ngram_range=(1, 3))
vectorizer.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.95, max_features=1000, min_df=2,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
X_train = vectorizer.transform(X_train).toarray()
X_train.shape
# Out:
# (1156, 1000)

# %%
X_train = np.insert(X_train, 0, train_source, axis=1)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, Y_train, test_size=0.33, random_state=seed)

# %%
train_data.Source.head()
# Out:
# 0    FORUMS
# 1    FORUMS
# 2      BLOG
# 3    FORUMS
# 4    FORUMS
# Name: Source, dtype: object

# %%
X_train.shape
# Out:
# (774, 1001)

# %%
X_valid.shape
# Out:
# (382, 1001)

# %%
params={
    'max_depth': [3,5,7,9,15], # 5 is good but takes too long in kaggle env
    'subsample': [0.4,0.6,0.8,1.0],
    'colsample_bytree': [0.5,0.7,0.9],
    'n_estimators': [800], #[1000,2000,3000]
    'reg_alpha': [0.01, 0.05, 0.1]
}

xgb_clf = xgboost.XGBClassifier(eval_set=[(X_valid, y_valid[:,1])])
rs = GridSearchCV(xgb_clf,
                  params,
                  cv=5,
                  scoring="log_loss",
                  n_jobs=1,
                  verbose=2)

# %%
rs.fit(X_train, y_train[:,1])
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.2s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.3s remaining:    0.0s
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.3s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   7.0s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.8s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   7.0s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.5s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.7s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.7s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.7s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.0s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.0s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.5s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.6s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.7s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.3s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.1s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.1s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.4s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   6.3s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.5s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.6s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   5.5s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=3, colsample_bytree=0.5 -   4.7s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.2s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.0s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.2s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.2s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.3s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.3s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.2s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.5s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.7s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.5s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.6s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.7s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.7s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.1s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.0s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.2s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.1s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.0s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.1s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.2s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.3s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.2s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.1s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.3s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.1s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  11.8s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.3s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.5s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.0s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.8s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.6s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.6s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.3s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.4s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.4s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  11.2s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.0s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.8s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.8s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.8s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.8s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=5, colsample_bytree=0.5 -  10.2s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.4s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.9s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   7.9s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   8.2s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=5, colsample_bytree=0.5 -   9.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.0s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.7s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.0s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.4s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.8s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.7s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.2s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.2s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.3s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.5s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.4s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.5s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.4s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.3s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  12.4s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.4s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.0s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.2s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.1s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.4s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   8.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   8.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   9.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -   8.9s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.2s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.5s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.8s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.5s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.0s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=7, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.7s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.7s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.8s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.7s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.5s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.5s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.5s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.4s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.3s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.5s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.4s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.3s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.8s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.5s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.1s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.8s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.4s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.2s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.5s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.2s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.8s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.3s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.5s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.3s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  12.2s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  12.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.3s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.8s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.1s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.6s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.5 -   9.2s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.8s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.5s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.6s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.0s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.8s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.3s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.4s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.9s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  10.7s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.5s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  12.1s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.1s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.5 -  11.5s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5 -   9.9s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  10.2s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  10.3s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  10.0s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.5 -   9.3s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.4s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  12.0s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  12.5s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.7s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.9s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.9s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.6s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.5
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.5 -  11.3s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.5
# ...
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  17.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  15.4s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  15.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  15.3s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  15.3s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  14.7s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  19.0s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  19.1s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  20.1s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  19.6s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  20.4s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  19.4s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  18.5s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  22.0s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  21.9s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  19.3s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  19.9s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  22.1s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  20.0s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  23.0s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=9, colsample_bytree=0.9 -  22.1s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  17.4s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.3s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  17.6s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  17.3s
# [CV] reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  17.5s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.9s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.8s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.9s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.4s
# [CV] reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.3s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.6s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.2s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  23.5s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  23.9s
# [CV] reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.1s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.3s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.8s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  22.3s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.2s
# [CV] reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.01, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.8s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  18.2s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.8s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.6s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  15.9s
# [CV] reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  15.9s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.0s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.2s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.6s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.4s
# [CV] reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.7s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.3s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.9s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.6s
# [CV] reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.6s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.4s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.8s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.2s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.9s
# [CV] reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.05, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.7s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.1s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.0s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.2s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.2s
# [CV] reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.4, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  16.7s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.3s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.9s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.6s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  18.8s
# [CV] reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.6, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  18.4s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.2s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.2s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.4s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.2s
# [CV] reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=0.8, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  19.9s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.0s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  21.3s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.3s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.1s
# [CV] reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9
# [CV]  reg_alpha=0.1, subsample=1.0, n_estimators=800, max_depth=15, colsample_bytree=0.9 -  20.5s
# [Parallel(n_jobs=1)]: Done 900 out of 900 | elapsed: 192.7min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1,
#        eval_set=[(array([[0., 0., ..., 0., 0.],
#        [0., 0., ..., 0., 0.],
#        ...,
#        [3., 0., ..., 0., 0.],
#        [2., 0., ..., 0., 0.]]), array([0., 0., ..., 1., 0.], dtype=float32...0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'reg_alpha': [0.01, 0.05, 0.1], 'subsample': [0.4, 0.6, 0.8, 1.0], 'n_estimators': [800], 'max_depth': [3, 5, 7, 9, 15], 'colsample_bytree': [0.5, 0.7, 0.9]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='log_loss', verbose=2)

# %%
best_est = rs.best_estimator_

# %%
best_est
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.5,
#        eval_set=[(array([[0., 0., ..., 0., 0.],
#        [0., 0., ..., 0., 0.],
#        ...,
#        [3., 0., ..., 0., 0.],
#        [2., 0., ..., 0., 0.]]), array([0., 0., ..., 1., 0.], dtype=float32))],
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=800, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.01, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1.0)

# %%
# xgb = xgboost.XGBClassifier(n_estimators=1500, learning_rate=0.05, gamma=0, subsample=0.75, colsample_bytree=1, max_depth=15)
# model_xgboost = xgb.fit(X_train, y_train[:,1], eval_set=[(X_valid, y_valid[:,1])])

# %%
# y_train_pred = model_xgboost.predict(X_train)
# Accuracy = accuracy_score(y_train, y_train_pred) * 100
# F1_score = f1_score(y_train, y_train_pred, average='weighted')

# %%
# custom_adam = keras.optimizers.Adam(lr=0.005, beta_1=0.9, beta_2=0.999, epsilon=1e-8)

# model = Sequential()
# model.add(Dense(128, activation='relu', input_dim=1001))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(2,
#                 activation='softmax',
#                 kernel_regularizer=L1L2(l1=0.0, l2=0.4)))

# %%
# precision = as_keras_metric(tf.metrics.precision)
# recall = as_keras_metric(tf.metrics.recall)

# model.compile(optimizer=custom_adam,
#               loss='categorical_crossentropy',
#               metrics=[auc_pr, 'accuracy'])

# model.fit_generator(generator=batch_generator_shuffle(X_train, y_train, 32),
#                       epochs=200, validation_data=(X_valid, y_valid),
#                       steps_per_epoch=X_train.shape[0] / 32)

# scores = model.evaluate(X_valid, y_valid)
# print ('\n')
# print (scores)

# %% [markdown]
# - 1 - 7: val_loss: 0.3521 - val_auc_pr: 0.9775 - val_acc: 0.8922
# - 2 - 200: val_loss: 0.6366 - val_auc_pr: 0.9851 - val_acc: 0.8889
# - 3 - val_loss: 1.3443 - val_auc_pr: 0.9714 - val_acc: 0.8246
#
# - [0.626494295846403, 0.983139782170065, 0.8856209134743884]

# %%
X_test = test_data['TRANS_CONV_TEXT']
X_test = preprocess_data(X_test, stemmer, lemma)
X_test = vectorizer.transform(X_test).toarray()

test_source = le.transform(test_data.Source)
X_test = np.insert(X_test, 0, test_source, axis=1)

# %%
X_test.shape
# Out:
# (571, 1001)

# %%
output = best_est.predict(X_test, 32)

# patient_tag = np.argmax(output, axis=1)
patient_tag = output
index = list(range(1, len(output)+1))
test_data_df = pd.DataFrame({'Index': index,'Patient_Tag': patient_tag}).set_index('Index')
test_data_df.Patient_Tag = test_data_df.Patient_Tag.astype('int')
test_data_df.to_csv('output.csv', columns=['Patient_Tag'] )

# %%
test_data_df.Patient_Tag.value_counts()
# Out:
# 0    503
# 1     68
# Name: Patient_Tag, dtype: int64

# %%
# model_json = model.to_json()
# with open(OUTPUT_FOLDER + "3_model.json", "w") as json_file:
#     json_file.write(model_json)

# model.save_weights(OUTPUT_FOLDER + "3_model.h5")

# %%
out = pd.read_csv('Models_and_output/1_output_84_06305.csv')
out.Patient_Tag.value_counts()

# %%
best_est
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.5,
#        eval_set=[(array([[0., 0., ..., 0., 0.],
#        [0., 0., ..., 0., 0.],
#        ...,
#        [3., 0., ..., 0., 0.],
#        [2., 0., ..., 0., 0.]]), array([0., 0., ..., 1., 0.], dtype=float32))],
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=800, n_jobs=1,
#        nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.01, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1.0)
