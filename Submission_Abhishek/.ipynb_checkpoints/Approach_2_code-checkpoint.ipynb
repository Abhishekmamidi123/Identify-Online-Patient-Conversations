# %% [markdown]
# # <center> Identify online patient conversations </center>
# ## Approach: Embedding + LSTM

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import HTML, display, SVG
from IPython.core import display as ICD
from plotly.offline import init_notebook_mode, iplot

import math
import keras
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Embedding, GRU
from keras.regularizers import L1L2
from keras.utils.np_utils import to_categorical
from keras.utils.vis_utils import model_to_dot

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import svm
from sklearn import tree
from sklearn import neighbors
from sklearn import linear_model

import nltk
import string
from nltk.stem import WordNetLemmatizer, SnowballStemmer

import warnings
warnings.filterwarnings('ignore')
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def batch_generator_shuffle(X_data, y_data, batch_size):
    samples_per_epoch = X_data.shape[0]
    number_of_batches = samples_per_epoch/batch_size
    counter=0
    index = np.arange(np.shape(y_data)[0])
    np.random.shuffle(index)
    while 1:
        index_batch = index[batch_size*counter:batch_size*(counter+1)]
        X_batch = X_data[index_batch,:]
        y_batch = y_data[index_batch]
        counter += 1
        yield X_batch,y_batch
        if (counter > number_of_batches):
            np.random.shuffle(index)
            counter=0

# %%
def as_keras_metric(method):
    import functools
    from keras import backend as K
    import tensorflow as tf
    @functools.wraps(method)
    def wrapper(self, args, **kwargs):
        """ Wrapper for turning tensorflow metrics into keras metrics """
        value, update_op = method(self, args, **kwargs)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([update_op]):
            value = tf.identity(value)
        return value
    return wrapper

@as_keras_metric
def auc_pr(y_true, y_pred, curve='PR'):
    return tf.metrics.auc(y_true, y_pred, curve=curve)

# %%
seed = 13
stemmer = SnowballStemmer("english")
lemma = WordNetLemmatizer()

le = LabelEncoder()

# %%
SOURCE_FOLDER = 'dataset/'
OUTPUT_FOLDER = 'Models_and_output/'

# %%
train_data = pd.read_csv(SOURCE_FOLDER + 'train.csv', encoding='ISO-8859-1')
test_data = pd.read_csv(SOURCE_FOLDER + 'test.csv', encoding='utf8')
test_data = test_data[test_data.columns[1:-1]]

# %%
train_data = train_data[train_data['TRANS_CONV_TEXT'].notnull()]

# %%
le.fit(train_data.Source)
train_source = le.transform(train_data.Source)

train_data.Patient_Tag.value_counts().plot('bar')

# %%
X_train = train_data['TRANS_CONV_TEXT']
Y_train = train_data['Patient_Tag']
Y_train = to_categorical(Y_train)

# %%
def preprocess_data(X_train, stemmer, lemma):
    preprocessed_data = []
    trans = str.maketrans('/(){}', ' ' * 5)
    trans_punc = str.maketrans('', '', string.punctuation)

    for text in X_train:
        text = text.lower().translate(trans)
        text = text.translate(trans_punc)
        text = [lemma.lemmatize(word) for word in text.split()]
        preprocessed_data.append(' '.join(text))

    return preprocessed_data

# %%
preprocessed_data = preprocess_data(X_train, stemmer, lemma)

# %%
preprocessed_data[-1]
# Out:
# 'i went through a sleep study ahi severe at 95 and titration test in late 2011 but wa never able to sleep effectively i own the system one series 50 650 bipap pro that i wa prescribed and an opus 360 nasal pillow assembly both are essentially unused im about 20 pound lighter than i wa back then and my sleeping seems to be a little bit better now than it wa back then whats the best way of trying to address my sleep apnea again is it ok to just try my existing machine and setting and adjust using sleepyhead do i need to go back to the doc and or do another sleep study are there any particularly good mask since 2011 that might be better than what i have ive spent the last three week dealing with a father with congestive heart failure and id like to try and do what i can to avoid that'

# %%
t = Tokenizer()
t.fit_on_texts(preprocessed_data)
encoded_lines = t.texts_to_sequences(preprocessed_data)

# %%
number_of_words = len(t.word_index) + 1
max_length_of_input = 1000
embedding_vector_length = 32

# %%
X_train = sequence.pad_sequences(encoded_lines, max_length_of_input)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, Y_train, test_size=0.33, random_state=seed)

# %%
model = Sequential()
model.add(Embedding(number_of_words, embedding_vector_length, input_length = max_length_of_input))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(2, activation = 'softmax'))

# %%
precision = as_keras_metric(tf.metrics.precision)
recall = as_keras_metric(tf.metrics.recall)

model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=[auc_pr, 'accuracy'])

mc = keras.callbacks.ModelCheckpoint('weights{epoch:02d}.h5', 
                                     save_weights_only=True, period=5)

# Try 40 epochs
model.fit_generator(generator=batch_generator_shuffle(X_train, y_train, 32),
                      epochs=40, validation_data=(X_valid, y_valid),
                      steps_per_epoch=X_train.shape[0] / 32, callbacks=[mc])

scores = model.evaluate(X_valid, y_valid)
print ('\n')
print (scores)
# Out:
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# Epoch 1/40
# 25/24 [===============================] - 34s 1s/step - loss: 0.5650 - auc_pr: 0.7297 - acc: 0.7808 - val_loss: 0.4971 - val_auc_pr: 0.7784 - val_acc: 0.7906
# Epoch 2/40
# 25/24 [===============================] - 33s 1s/step - loss: 0.4479 - auc_pr: 0.8102 - acc: 0.7906 - val_loss: 0.3845 - val_auc_pr: 0.8489 - val_acc: 0.7880
# Epoch 3/40
# 25/24 [===============================] - 41s 2s/step - loss: 0.2160 - auc_pr: 0.8801 - acc: 0.9147 - val_loss: 0.4453 - val_auc_pr: 0.8967 - val_acc: 0.8508
# Epoch 4/40
# 25/24 [===============================] - 37s 1s/step - loss: 0.0915 - auc_pr: 0.9110 - acc: 0.9762 - val_loss: 0.3977 - val_auc_pr: 0.9244 - val_acc: 0.8717
# Epoch 5/40
# 25/24 [===============================] - 36s 1s/step - loss: 0.0234 - auc_pr: 0.9342 - acc: 0.9912 - val_loss: 0.4473 - val_auc_pr: 0.9420 - val_acc: 0.8743
# Epoch 6/40
# 25/24 [===============================] - 25s 1s/step - loss: 0.0050 - auc_pr: 0.9475 - acc: 1.0000 - val_loss: 0.4327 - val_auc_pr: 0.9527 - val_acc: 0.8848
# Epoch 7/40
# 25/24 [===============================] - 25s 1s/step - loss: 0.0054 - auc_pr: 0.9565 - acc: 0.9987 - val_loss: 0.4682 - val_auc_pr: 0.9597 - val_acc: 0.8874
# Epoch 8/40
# 25/24 [===============================] - 26s 1s/step - loss: 0.0018 - auc_pr: 0.9621 - acc: 1.0000 - val_loss: 0.5139 - val_auc_pr: 0.9642 - val_acc: 0.8770
# Epoch 9/40
# 25/24 [===============================] - 26s 1s/step - loss: 0.0014 - auc_pr: 0.9658 - acc: 1.0000 - val_loss: 0.5474 - val_auc_pr: 0.9673 - val_acc: 0.8770
# Epoch 10/40
# 25/24 [===============================] - 25s 1s/step - loss: 9.6558e-04 - auc_pr: 0.9684 - acc: 1.0000 - val_loss: 0.5754 - val_auc_pr: 0.9695 - val_acc: 0.8796
# Epoch 11/40
# 25/24 [===============================] - 26s 1s/step - loss: 7.8798e-04 - auc_pr: 0.9703 - acc: 1.0000 - val_loss: 0.5757 - val_auc_pr: 0.9711 - val_acc: 0.8770
# Epoch 12/40
# 25/24 [===============================] - 26s 1s/step - loss: 5.6814e-04 - auc_pr: 0.9717 - acc: 1.0000 - val_loss: 0.5882 - val_auc_pr: 0.9723 - val_acc: 0.8796
# Epoch 13/40
# 25/24 [===============================] - 26s 1s/step - loss: 4.7671e-04 - auc_pr: 0.9728 - acc: 1.0000 - val_loss: 0.5984 - val_auc_pr: 0.9732 - val_acc: 0.8796
# Epoch 14/40
# 25/24 [===============================] - 25s 1s/step - loss: 4.3476e-04 - auc_pr: 0.9736 - acc: 1.0000 - val_loss: 0.6089 - val_auc_pr: 0.9739 - val_acc: 0.8822
# Epoch 15/40
# 25/24 [===============================] - 25s 1s/step - loss: 3.5357e-04 - auc_pr: 0.9743 - acc: 1.0000 - val_loss: 0.6194 - val_auc_pr: 0.9745 - val_acc: 0.8796
# Epoch 16/40
# 25/24 [===============================] - 26s 1s/step - loss: 3.3113e-04 - auc_pr: 0.9749 - acc: 1.0000 - val_loss: 0.6295 - val_auc_pr: 0.9751 - val_acc: 0.8848
# Epoch 17/40
# 25/24 [===============================] - 26s 1s/step - loss: 3.5244e-04 - auc_pr: 0.9754 - acc: 1.0000 - val_loss: 0.6044 - val_auc_pr: 0.9756 - val_acc: 0.8927
# Epoch 18/40
# 25/24 [===============================] - 25s 1s/step - loss: 2.9790e-04 - auc_pr: 0.9758 - acc: 1.0000 - val_loss: 0.6260 - val_auc_pr: 0.9760 - val_acc: 0.8927
# Epoch 19/40
# 25/24 [===============================] - 26s 1s/step - loss: 2.4139e-04 - auc_pr: 0.9762 - acc: 1.0000 - val_loss: 0.6434 - val_auc_pr: 0.9763 - val_acc: 0.8822
# Epoch 20/40
# 25/24 [===============================] - 25s 1s/step - loss: 2.1018e-04 - auc_pr: 0.9765 - acc: 1.0000 - val_loss: 0.6528 - val_auc_pr: 0.9766 - val_acc: 0.8848
# Epoch 21/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.9323e-04 - auc_pr: 0.9768 - acc: 1.0000 - val_loss: 0.6598 - val_auc_pr: 0.9769 - val_acc: 0.8874
# Epoch 22/40
# 25/24 [===============================] - 25s 1s/step - loss: 4.4070e-04 - auc_pr: 0.9770 - acc: 1.0000 - val_loss: 0.6588 - val_auc_pr: 0.9771 - val_acc: 0.8770
# Epoch 23/40
# 25/24 [===============================] - 25s 1s/step - loss: 2.2504e-04 - auc_pr: 0.9772 - acc: 1.0000 - val_loss: 0.6846 - val_auc_pr: 0.9774 - val_acc: 0.8770
# Epoch 24/40
# 25/24 [===============================] - 25s 1s/step - loss: 2.1223e-04 - auc_pr: 0.9775 - acc: 1.0000 - val_loss: 0.6860 - val_auc_pr: 0.9775 - val_acc: 0.8717
# Epoch 25/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.8687e-04 - auc_pr: 0.9776 - acc: 1.0000 - val_loss: 0.6901 - val_auc_pr: 0.9777 - val_acc: 0.8743
# Epoch 26/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.5024e-04 - auc_pr: 0.9778 - acc: 1.0000 - val_loss: 0.6953 - val_auc_pr: 0.9778 - val_acc: 0.8743
# Epoch 27/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.4265e-04 - auc_pr: 0.9779 - acc: 1.0000 - val_loss: 0.7002 - val_auc_pr: 0.9779 - val_acc: 0.8743
# Epoch 28/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.2743e-04 - auc_pr: 0.9780 - acc: 1.0000 - val_loss: 0.7077 - val_auc_pr: 0.9780 - val_acc: 0.8743
# Epoch 29/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.2711e-04 - auc_pr: 0.9780 - acc: 1.0000 - val_loss: 0.7076 - val_auc_pr: 0.9781 - val_acc: 0.8743
# Epoch 30/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.4673e-04 - auc_pr: 0.9781 - acc: 1.0000 - val_loss: 0.7212 - val_auc_pr: 0.9782 - val_acc: 0.8743
# Epoch 31/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.1209e-04 - auc_pr: 0.9782 - acc: 1.0000 - val_loss: 0.7290 - val_auc_pr: 0.9783 - val_acc: 0.8717
# Epoch 32/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.0124e-04 - auc_pr: 0.9783 - acc: 1.0000 - val_loss: 0.7354 - val_auc_pr: 0.9783 - val_acc: 0.8743
# Epoch 33/40
# 25/24 [===============================] - 25s 1s/step - loss: 9.5497e-05 - auc_pr: 0.9783 - acc: 1.0000 - val_loss: 0.7410 - val_auc_pr: 0.9783 - val_acc: 0.8770
# Epoch 34/40
# 25/24 [===============================] - 25s 1s/step - loss: 9.3211e-05 - auc_pr: 0.9784 - acc: 1.0000 - val_loss: 0.7450 - val_auc_pr: 0.9784 - val_acc: 0.8770
# Epoch 35/40
# 25/24 [===============================] - 25s 1s/step - loss: 1.1313e-04 - auc_pr: 0.9784 - acc: 1.0000 - val_loss: 0.7316 - val_auc_pr: 0.9784 - val_acc: 0.8770
# Epoch 36/40
# 25/24 [===============================] - 25s 1s/step - loss: 8.6136e-05 - auc_pr: 0.9784 - acc: 1.0000 - val_loss: 0.7369 - val_auc_pr: 0.9785 - val_acc: 0.8743
# Epoch 37/40
# 25/24 [===============================] - 25s 1s/step - loss: 7.4760e-05 - auc_pr: 0.9785 - acc: 1.0000 - val_loss: 0.7463 - val_auc_pr: 0.9785 - val_acc: 0.8743
# Epoch 38/40
# 25/24 [===============================] - 25s 1s/step - loss: 9.1104e-05 - auc_pr: 0.9785 - acc: 1.0000 - val_loss: 0.7400 - val_auc_pr: 0.9785 - val_acc: 0.8770
# Epoch 39/40
# 25/24 [===============================] - 25s 1s/step - loss: 6.8068e-05 - auc_pr: 0.9785 - acc: 1.0000 - val_loss: 0.7379 - val_auc_pr: 0.9786 - val_acc: 0.8796
# Epoch 40/40
# 25/24 [===============================] - 25s 1s/step - loss: 6.9049e-05 - auc_pr: 0.9786 - acc: 1.0000 - val_loss: 0.7449 - val_auc_pr: 0.9786 - val_acc: 0.8796
# 382/382 [==============================] - 2s 5ms/step
#
#
# [0.7449118510590798, 0.9781570865221673, 0.8795811502721297]

# %% [markdown]
# - [0.626494295846403, 0.983139782170065, 0.8856209134743884]
# - 1 - 7: val_loss: 0.3521 - val_auc_pr: 0.9775 - val_acc: 0.8922
# - 2 - 200: val_loss: 0.6366 - val_auc_pr: 0.9851 - val_acc: 0.8889
# - 3 - val_loss: 1.3443 - val_auc_pr: 0.9714 - val_acc: 0.8246
# - 6 - val_loss: 0.8538 - val_auc_pr: 0.9799 - val_acc: 0.8796
# - 7 - val_loss: 0.9069 - val_auc_pr: 0.9755 - val_acc: 0.8848

# %%
X_test = test_data['TRANS_CONV_TEXT']
X_test = preprocess_data(X_test, stemmer, lemma)
X_test = t.texts_to_sequences(X_test)
X_test = sequence.pad_sequences(X_test, max_length_of_input)

# %%
X_test
# Out:
# array([[   0,    0,    0, ..., 3934,  743,  982],
#        [   0,    0,    0, ...,  929,  395,  176],
#        [   0,    0,    0, ..., 7374, 7375, 4014],
#        ...,
#        [   0,    0,    0, ...,  114,  296,   35],
#        [   0,    0,    0, ...,   68,   12,    7],
#        [   0,    0,    0, ...,   26,  172,  668]], dtype=int32)

# %%
from keras.models import model_from_json

model_35 = model.to_json()
loaded_model_35 = model_from_json(model_35)
loaded_model_35.load_weights("weights25.h5")

loaded_model_35

# %%
from keras.utils import plot_model 

plot_model(model, show_shapes=True, to_file='model.png')

# %%
output = model.predict(X_test, 32)

patient_tag = np.argmax(output, axis=1)
index = list(range(1, len(output)+1))
test_data_df = pd.DataFrame({'Index': index,'Patient_Tag': patient_tag}).set_index('Index')
test_data_df.to_csv('output.csv', columns=['Patient_Tag'])

# %%
test_data_df.Patient_Tag.value_counts()
# Out:
# 0    454
# 1    117
# Name: Patient_Tag, dtype: int64

# %%
model_json = model.to_json()
with open(OUTPUT_FOLDER + "15_model.json", "w") as json_file:
    json_file.write(model_json)

model.save_weights(OUTPUT_FOLDER + "15_model.h5")

# %%
out1 = pd.read_csv('Models_and_output/10_ensemble_output_92_99475.csv')
out1.Patient_Tag.value_counts()
# Out:
# 0    465
# 1    106
# Name: Patient_Tag, dtype: int64

# %%
#446 125

# %%
test_data_df.Patient_Tag.corr(out1.Patient_Tag)
# Out:
# -0.04101691649275391

# %%
dummy_data = pd.read_csv(SOURCE_FOLDER + 'train.csv', encoding='ISO-8859-1')

# %%
dummy_data.head()
# Out:
#    Source                                              Host  \
# 0  FORUMS                                    cafepharma.com
# 1  FORUMS                                 www.patient.co.uk
# 2    BLOG  http://abcnewsradioonline.com/entertainment-news
# 3  FORUMS                             www.cancer-forums.net
# 4  FORUMS                                  www.diyaudio.com
#
#                                                 Link   Date(ET)     Time(ET)  \
# 0  http://cafepharma.com/boards/threads/epstein.5...  6/15/2016     13:58:00
# 1  http://www.patient.co.uk/forums/discuss/enlarg...   5/7/2016  0.820833333
# 2  http://abcnewsradioonline.com/entertainment-ne...  4/14/2016     15:00:38
# 3  http://www.cancer-forums.net/viewtopic.php?f=1...  6/18/2016     20:46:00
# 4  http://www.diyaudio.com/forums/lounge/292252-d...  6/15/2016      3:26:00
#
#          time(GMT)                                              Title  \
# 0  6/15/2016 23:28                                            Epstein
# 1      42498.21667               Enlarged Heart.Thread Enlarged Heart
# 2   4/15/2016 0:30  Queen Latifah Joins American Heart Association...
# 3   6/19/2016 6:16                                           Bulaemia
# 4  6/15/2016 12:56               DIY Silver interconnects and RCAs???
#
#                                      TRANS_CONV_TEXT  Patient_Tag
# 0  I don't disagree with you in principle. I'm ju...            0
# 1  I am always dizzy I get dizzy standing up so I...            1
# 2  Axelle/Bauer-Griffin/FilmMagic(NEW YORK) -- Qu...            0
# 3  I am 17 and I have been throwing up for about ...            1
# 4  Quote: Originally Posted by Boyan Silyavski Wa...            0

# %%
dummy_data.Patient_Tag.value_counts().plot('bar')

# %%
train_data
# Out:
#         Source                                               Host  \
# 0       FORUMS                                     cafepharma.com
# 1       FORUMS                                  www.patient.co.uk
# 2         BLOG   http://abcnewsradioonline.com/entertainment-news
# 3       FORUMS                              www.cancer-forums.net
# 4       FORUMS                                   www.diyaudio.com
# 5       FORUMS                                forum.cyclinguk.org
# 6       FORUMS                                     www.reddit.com
# 7         BLOG                    http://quranfruitz.blogspot.com
# 8       FORUMS                                         hmnews.org
# 9       FORUMS                                 www.cafepharma.com
# 10      FORUMS                                    modelmayhem.com
# 11      FORUMS                            blueheronhealthnews.com
# 12        BLOG      http://medicaldevicemarkettrends.blogspot.com
# 13        BLOG                   http://www.becomerichfaster.com/
# 14      FORUMS                                       www.fark.com
# 15        BLOG                             http://news.health.com
# 16      FORUMS                                  finance.yahoo.com
# 17        BLOG                            http://wwj.cbslocal.com
# 18      FORUMS                       guboards.spokesmanreview.com
# 19        BLOG                       http://mostdiet.blogspot.com
# 20        BLOG          http://eliteathletictraining.blogspot.com
# 21      FORUMS                                     alkpathway.com
# 22      FORUMS                              www.explorerforum.com
# 23      FORUMS                          stltommorow.proboards.com
# 24        BLOG                          http://www.4-traders.com/
# 25        BLOG                               feedproxy.google.com
# 26        BLOG                http://befitweightloss.blogspot.com
# 27        BLOG                               http://drkelley.info
# 28      FORUMS                                 www.xboxhacker.org
# 29        BLOG                http://dangchuatinhcon.blogspot.com
# ...        ...                                                ...
# 1127      BLOG                       http://whangaed.blogspot.com
# 1128      BLOG                              http://blog.heart.org
# 1129    FORUMS                                   boards.4chan.org
# 1130    FORUMS                            www.theboltonnews.co.uk
# 1131      BLOG            http://elbiruniblogspotcom.blogspot.com
# 1132      BLOG                               morediabetesinfo.com
# 1133    FORUMS                               www.emmasdiary.co.uk
# 1134      BLOG            http://sciencedaily.com/news/mind_brain
# 1135      BLOG                           http://socialcafemag.com
# 1136      BLOG                     http://sonoranweeklyreview.com
# 1137    FORUMS                        emotivalounge.proboards.com
# 1138    FORUMS                                      allnurses.com
# 1139      BLOG              easyhealthydietingguides.blogspot.com
# 1140    FORUMS                                    www.medhelp.org
# 1141      BLOG                          http://www.mmafights.biz/
# 1142      BLOG                    http://ifannuke.livejournal.com
# 1143  FACEBOOK                                                NaN
# 1144  Facebook                                                NaN
# 1145      BLOG                          http://www.slideshare.net
# 1146  Facebook                                                NaN
# 1147    FORUMS                            www.healthcaremagic.com
# 1148    FORUMS                           forums.studentdoctor.net
# 1149      BLOG  http://sidelongglancesofapigeonkicker.blogspot...
# 1150      BLOG     http://coordination-bootcamp-ex-dyl.tumblr.com
# 1151    FORUMS                            www.icdsupportgroup.org
# 1152      BLOG           http://medicalxpress.com/cardiology-news
# 1153   YOUTUBE                                        youtube.com
# 1154    FORUMS                                   www.cpaptalk.com
# 1155    FORUMS                          ourfantasycastle.yuku.com
# 1156    FORUMS                                   www.cpaptalk.com
#
#                                                    Link   Date(ET)  \
# 0     http://cafepharma.com/boards/threads/epstein.5...  6/15/2016
# 1     http://www.patient.co.uk/forums/discuss/enlarg...   5/7/2016
# 2     http://abcnewsradioonline.com/entertainment-ne...  4/14/2016
# 3     http://www.cancer-forums.net/viewtopic.php?f=1...  6/18/2016
# 4     http://www.diyaudio.com/forums/lounge/292252-d...  6/15/2016
# 5     http://forum.cyclinguk.org/viewtopic.php?f=24&...   4/6/2016
# 6     https://www.reddit.com/r/todayilearned/comment...   5/2/2016
# 7     http://quranfruitz.blogspot.com/2016/02/causes...  2/28/2016
# 8     http://hmnews.org/health-care-news/cluster8641...  6/15/2016
# 9     http://www.cafepharma.com/boards/threads/nomin...  4/29/2016
# 10    http://www.modelmayhem.com/forums/post/960268/...  7/15/2016
# 11    http://blueheronhealthnews.com/site/2016/02/22...  2/22/2016
# 12    http://medicaldevicemarkettrends.blogspot.com/...  4/26/2016
# 13    http://www.becomerichfaster.com/money-morning/...  3/18/2016
# 14    http://www.fark.com/comments/9116353/Now-is-wh...  4/21/2016
# 15    http://news.health.com/2016/03/28/do-it-yourse...  3/28/2016
# 16    http://finance.yahoo.com/mbview/threadview/?&b...  6/17/2016
# 17    http://detroit.cbslocal.com/2016/03/06/former-...   3/6/2016
# 18    http://guboards.spokesmanreview.com/showthread...  7/25/2016
# 19    http://mostdiet.blogspot.com/2016/04/pot-belly...   4/3/2016
# 20    http://eliteathletictraining.blogspot.com/2016...  6/21/2016
# 21      http://alkpathway.com/50-cytokines-tnf-il1-il6/  4/26/2016
# 22    http://www.explorerforum.com/forums/showthread...   4/7/2016
# 23    http://stltommorow.proboards.com/thread/8090/l...  6/20/2016
# 24    http://www.4-traders.com/NOVARTIS-AG-9364983/n...   4/2/2016
# 25    http://feedproxy.google.com/~r/ArtesiaNews/~3/...  7/22/2016
# 26    http://befitweightloss.blogspot.com/2016/03/gr...  3/22/2016
# 27    http://www.drkelley.info/2016/04/06/would-you-...   4/6/2016
# 28    http://www.xboxhacker.org/index.php?topic=7224...  6/18/2016
# 29    http://dangchuatinhcon.blogspot.com/2016/06/vi...  6/19/2016
# ...                                                 ...        ...
# 1127  http://whangaed.blogspot.com/2016/04/pain-acut...  4/14/2016
# 1128  http://news.heart.org/post-a-red-sock-selfie-a...  4/14/2016
# 1129  http://boards.4chan.org/ck/thread/7903564#p790...  7/23/2016
# 1130  http://www.theboltonnews.co.uk/li/districtnews...  4/28/2016
# 1131  http://elbiruniblogspotcom.blogspot.com/2016/0...   4/4/2016
# 1132  http://morediabetesinfo.com/flu-vaccine-may-re...  7/28/2016
# 1133  http://www.emmasdiary.co.uk/forums/immunisatio...  6/17/2016
# 1134  https://www.sciencedaily.com/releases/2016/04/...   4/3/2016
# 1135  http://socialcafemag.com/2016/06/swollen-ankle...  6/15/2016
# 1136  http://sonoranweeklyreview.com/concordia-healt...  4/21/2016
# 1137  http://emotivalounge.proboards.com/thread/4652...   4/4/2016
# 1138  http://allnurses.com/nursing-patient-medicatio...  6/28/2016
# 1139  http://easyhealthydietingguides.blogspot.com/2...  7/31/2016
# 1140  http://www.medhelp.org/posts/show/2869371#post...  4/23/2016
# 1141  http://www.mmafights.biz/bellator-releases-spe...  6/15/2016
# 1142          http://ifannuke.livejournal.com/1837.html  3/19/2016
# 1143  http://www.facebook.com/permalink.php?id=13711...  7/31/2016
# 1144  http://www.facebook.com/permalink.php?id=10153...  12-Jun-16
# 1145  http://www.slideshare.net/JenanM/heart-failure...  6/26/2016
# 1146  http://facebook.com/157929034256616_1006890192...  4/11/2016
# 1147  http://www.healthcaremagic.com/questions/What-...   3/2/2016
# 1148  http://forums.studentdoctor.net/threads/isolat...  4/26/2016
# 1149  http://sidelongglancesofapigeonkicker.blogspot...  6/15/2016
# 1150  http://coordination-bootcamp-ex-dyl.tumblr.com...  6/16/2016
# 1151  http://www.icdsupportgroup.org/board/viewtopic...  5/11/2016
# 1152  http://medicalxpress.com/news/2016-04-saxaglip...  4/26/2016
# 1153             http://youtube.com/watch?v=3Z9yiPdLDO4  7/20/2016
# 1154  http://www.cpaptalk.com/viewtopic.php?t=110350...  2/10/2016
# 1155  http://ourfantasycastle.yuku.com/reply/554464/...  7/14/2016
# 1156  http://www.cpaptalk.com/viewtopic.php?t=111651...  4/24/2016
#
#          Time(ET)                             time(GMT)  \
# 0        13:58:00                       6/15/2016 23:28
# 1     0.820833333                           42498.21667
# 2        15:00:38                        4/15/2016 0:30
# 3        20:46:00                        6/19/2016 6:16
# 4         3:26:00                       6/15/2016 12:56
# 5         5:50:00                        4/6/2016 15:20
# 6     0.047916667                           42492.44375
# 7         3:20:00                       2/28/2016 13:50
# 8        17:16:00                        6/16/2016 2:46
# 9        23:46:00                        4/30/2016 9:16
# 10       15:49:00                                   NaN
# 11       18:52:00                       2/22/2016 23:52
# 12        5:48:00                       4/26/2016 15:18
# 13       19:00:28                        3/19/2016 4:30
# 14       10:17:00                       4/21/2016 19:47
# 15       15:37:07                        3/29/2016 1:07
# 16        5:24:00                       6/17/2016 14:54
# 17       12:45:51                        3/6/2016 23:15
# 18       10:42:00                                   NaN
# 19        3:18:00                        4/3/2016 12:48
# 20       16:08:00                        6/22/2016 1:38
# 21       22:51:00                        4/27/2016 8:21
# 22       21:47:00                         4/8/2016 7:17
# 23       12:40:09                       6/20/2016 22:10
# 24       11:01:13                        4/2/2016 20:31
# 25       15:56:40                                   NaN
# 26       12:51:00                       3/22/2016 22:21
# 27       15:03:04                         4/7/2016 0:33
# 28       23:03:00                        6/19/2016 8:33
# 29       19:37:00                        6/20/2016 5:07
# ...           ...                                   ...
# 1127     22:02:00                        4/15/2016 7:32
# 1128      8:40:15                       4/14/2016 18:10
# 1129      0:26:00                                   NaN
# 1130      0:13:00                        4/28/2016 9:43
# 1131     10:33:00                        4/4/2016 20:03
# 1132      3:00:18                                   NaN
# 1133     16:58:00                        6/18/2016 2:28
# 1134     15:21:13                         4/4/2016 0:51
# 1135     11:43:26                       6/15/2016 21:13
# 1136     19:50:46                        4/22/2016 5:20
# 1137     15:36:13                         4/5/2016 1:06
# 1138      5:40:00                       6/28/2016 15:10
# 1139      4:01:00                                   NaN
# 1140      8:00:00                       4/23/2016 17:30
# 1141      8:38:53                       6/15/2016 18:08
# 1142     20:39:08                        3/20/2016 6:09
# 1143     18:48:00                                   NaN
# 1144      7:45 PM                       6/12/2016 19:45
# 1145     15:01:49                        6/27/2016 0:31
# 1146      3:33 PM                       4/11/2016 15:33
# 1147     19:00:00                         3/3/2016 5:30
# 1148     16:47:00                        4/27/2016 2:17
# 1149      9:31:00                       6/15/2016 19:01
# 1150     20:02:07                        6/17/2016 5:32
# 1151  0.052777778                           42501.44861
# 1152     16:30:01                        4/27/2016 2:00
# 1153     11:25:11  Ted Rogers Centre for Heart Research
# 1154  0.471527778                           42410.67986
# 1155      5:16:06                                   NaN
# 1156     20:45:00                        4/25/2016 6:15
#
#                                                   Title  \
# 0                                               Epstein
# 1                  Enlarged Heart.Thread Enlarged Heart
# 2     Queen Latifah Joins American Heart Association...
# 3                                              Bulaemia
# 4                  DIY Silver interconnects and RCAs???
# 5                                     Personal Question
# 6     TIL that CVS took a $2 billion hit to annual s...
# 7            Causes of Low Blood Pressure(Hypo tension)
# 8     Sleep disorders may predict heart events after...
# 9             Nominations for worst manager at Novartis
# 10                                                  NaN
# 11    Comment on This ?Low Blood Pressure Diet? is T...
# 12    Blood Pressure Monitoring and Testing Market t...
# 13    How Much Tax Can a Tax Man Tax if a Tax Man Ca...
# 14                   (9116353) Now is when doves cry :(
# 15    Do-It-Yourself Blood Pressure Checks May Help ...
# 16                How big is the ALS market ? Anybody !
# 17    Former First Lady Nancy Reagan Dies At 94 In C...
# 18                                                  NaN
# 19                     Pot belly ups heart failure risk
# 20                    Is Exercise Better Than Medicine?
# 21    50 Moreover, the cytokines like TNF-??, IL-1??...
# 22                                         Body Bushing
# 23             The ?low-hanging fruit? of police reform
# 24    NOVARTIS : New analyses show Novartis' Entrest...
# 25                                                  NaN
# 26            Grape Eaters Tend To Have Healthier Diets
# 27       Would YOU know you were having a heart attack?
# 28          Botulism is outlined beyond grate hospital.
# 29                          Vi?c Gn Gi? Ph?p Th?nh Th?
# ...                                                 ...
# 1127                                  PAIN - ACUTE PAIN
# 1128  Post a red-sock selfie and help raise awarenes...
# 1129                                                NaN
# 1130  'He was trying to self-diagnose and came a cro...
# 1131  Study results show bypass surgery extends live...
# 1132                                                NaN
# 1133                              2 month immunisations
# 1134  Improving depression symptoms can reduce risk ...
# 1135  Swollen Ankles? Find out All about Water Reten...
# 1136  Concordia Healthcare Shares Surge 25% on Repor...
# 1137                          Does Life Change at 50???
# 1138    Holding "Ordered Meds"..... What are the rules?
# 1139                                                NaN
# 1140                    Right side heart valves slower?
# 1141    Bellator Releases Special Video For Kimbo Slice
# 1142  Including This In The Regular Diet Is A Simple...
# 1143                                                NaN
# 1144                                                NaN
# 1145                        Heart failure in_pediatrics
# 1146                                                NaN
# 1147  What causes pain in joints and muscles along w...
# 1148                   Isolated diastolic heart failure
# 1149                          Yumi Shirakawa Remembered
# 1150         The Medicinal Power As regards Naturopathy
# 1151  for those on Coreg... why and what is your dos...
# 1152  Saxagliptin, sitagliptin don't up hospitalized...
# 1153                                                NaN
# 1154                         ASV questions and concerns
# 1155                                                NaN
# 1156           Want to Try Again--Data From First Night
#
#                                         TRANS_CONV_TEXT  Patient_Tag
# 0     I don't disagree with you in principle. I'm ju...            0
# 1     I am always dizzy I get dizzy standing up so I...            1
# 2     Axelle/Bauer-Griffin/FilmMagic(NEW YORK) -- Qu...            0
# 3     I am 17 and I have been throwing up for about ...            1
# 4     Quote: Originally Posted by Boyan Silyavski Wa...            0
# 5     Theres a discussion about recumbent power on B...            0
# 6     Of course! I just got diagnosed with congestiv...            1
# 7     Blood pressure is a measurement of the pressur...            0
# 8     Other Sleep disorders may predict heart events...            0
# 9     worse manager ever??? LS out of Richmond. Ugh!...            0
# 10    Looknsee Photography wrote: When I was living ...            1
# 11    Posted by: Christian Goodman A new study revea...            0
# 12    Transparency Market Research has published a n...            0
# 13    It?s been a big week here in the UK. This week...            0
# 14    Russ1642 : So another anti-science anti-medici...            1
# 15    By Steven Reinberg HealthDay Reporter MONDAY, ...            0
# 16    that's not where the biggest opportunity is - ...            0
# 17    LOS ANGELES (AP) ? Former first lady Nancy Rea...            0
# 18    Originally Posted by Birddog Cause of death wa...            0
# 19    London: Obesity not only increases the risk of...            0
# 20    According to New York Times columnist, profess...            0
# 21    50 Moreover, the cytokines like TNF-??, IL-1??...            0
# 22    Thank you swshawaii, I plan on finishing it so...            1
# 23    A little more than a year ago, my colleagues a...            0
# 24    (4-traders.com) Novartis International AG / Ne...            0
# 25    STILLWATER, Okla. (AP) ? Medical examiner spok...            0
# 26    If you?re a regular eater of grapes, then the ...            0
# 27    Warning signs can vary wildly between men and ...            0
# 28    Blood pressure sometimes ski diagnosis. Doctor...            0
# 29    41. Excerpts from vietcatholic.net tabernacle ...            0
# ...                                                 ...          ...
# 1127  Basics in Pain Management Robin PLumer / Mick ...            0
# 1128  By AMERICAN HEART ASSOCIATION NEWS The ?Red St...            0
# 1129  >>7906334 (2/2) [spoiler]And I don't really ca...            1
# 1130  'He was trying to self-diagnose and came a cro...            0
# 1131  Study results show bypass surgery extends live...            0
# 1132  The flu vaccine may reduce the likelihood of b...            0
# 1133  Hi, I'm just wondering how your little ones re...            0
# 1134  A new study found that effectively treating de...            0
# 1135  Are the rings on your fingers feeling tight? O...            0
# 1136  The stock increased 25.24% or $7.79 on April 2...            0
# 1137  Very interesting question sidvicious, how have...            1
# 1138  As others have mentioned, know the patient's b...            0
# 1139  Congestive heart failure is actually a conditi...            0
# 1140  Your heart has a left and a right side. On the...            0
# 1141  Bellator MMA posted a special ?RIP? video for ...            0
# 1142  It regulates the hormone levels, boosts the he...            0
# 1143  Hi my name is Katie. Im a huge fan of Justin B...            1
# 1144  "  Best hospital in the world!!! I am a patien...            1
# 1145  presentation regarding investigations and trea...            0
# 1146  "  Just visited the Jason's Deli on Forest Hil...            0
# 1147  Hi Dear, Welcome to HCM. Understanding your co...            0
# 1148  Diastolic failure is defined as: increased end...            0
# 1149  Yumi Shirakawa poses with a fan at gathering i...            0
# 1150  Naturopathy focuses thanks to two areas for he...            0
# 1151  I an having terrible multiple side effects and...            1
# 1152  (HealthDay)?Use of saxagliptin or sitagliptin ...            0
# 1153  Description: A keynote address at the Ted Roge...            0
# 1154  Quote: : After publishing the first study that...            0
# 1155  Thank you.<br /><br /> What we know,<br /><br ...            1
# 1156  I went through a sleep study (AHI Severe at 95...            0
#
# [1156 rows x 9 columns]
